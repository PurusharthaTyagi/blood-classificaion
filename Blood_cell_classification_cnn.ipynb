# %% [markdown]
# # Blood Cell Subtype Classification

# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance as dist
import matplotlib.pyplot as plt
import os
import cv2
import seaborn as sns
from tqdm import tqdm 
from sklearn.utils import shuffle
from sklearn import decomposition
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf
import keras
from keras.applications.vgg16 import VGG16 
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
from keras.models import Sequential, Model 
# from keras.applications import DenseNet201
from keras.initializers import he_normal
from keras.layers import Lambda, SeparableConv2D, BatchNormalization, Dropout, MaxPooling2D, Input, Dense, Conv2D, Activation, Flatten 
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import imutils

# %% [markdown]
# # Object detection:
#
# did object detection using opencv by findig edges in the images the extract contours and from contours get image boxes

# %%
def findEdges(image):
    # find edges in image
    gray = cv2.GaussianBlur(image, (1, 1), 0)
    edged = cv2.Canny(gray, 100, 400)
    edged = cv2.dilate(edged, None, iterations=1)
    edged = cv2.erode(edged, None, iterations=1)
    return edged

# %%
def getImgContours(edged):
    # find contours in the edge map
    contours = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    contours = sorted(contours, key=lambda x: cv2.contourArea(x))
    return contours

# %%
def getBoxes(contours, orig):
    # get the boxes
    boxes = []
    centers = []
    for contour in contours:
        box = cv2.minAreaRect(contour)
        box = cv2.cv.BoxPoints(box) if imutils.is_cv2() else cv2.boxPoints(box)
        box = np.array(box, dtype="int")
        (tl, tr, br, bl) = box
        if (dist.euclidean(tl, bl)) > 0 and (dist.euclidean(tl, tr)) > 0:
            boxes.append(box)
    return boxes

# %% [markdown]
# # Loading Data:
#
# Load_data function that loads images and labels from the Train and Test folders and combines the datasets to return Image-Label pairs
# combining the Train/Test folders and recreate the dataset .

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -u "/content/drive/My Drive/jump.zip" -d "/content/drive/My Drive/blood_classification"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8050.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8167.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8283.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8324.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8379.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8577.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8587.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8655.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8701.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_872.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8864.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8931.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_8989.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_899.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9320.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9338.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9682.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_969.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9729.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9799.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9866.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/LYMPHOCYTE/_9_9954.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1173.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1276.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1285.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1400.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1483.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1511.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1579.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1582.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1683.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1737.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1786.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_180.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1814.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_1825.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_185.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2154.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2170.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2188.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2202.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2232.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2321.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2420.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2477.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2491.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2522.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2571.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_260.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2610.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2648.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2783.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2814.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2936.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_2955.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3066.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3091.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3191.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3238.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3455.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3464.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3522.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3605.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3743.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_375.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3861.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3912.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_3998.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4033.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4059.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4102.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4123.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4225.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4296.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_435.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4407.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4446.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4528.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_453.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4560.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4563.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4650.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4667.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4715.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4745.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4762.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4778.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4791.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4862.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4872.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4881.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4884.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_4925.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_494.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5029.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5074.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_508.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5081.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5144.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5156.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5200.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5209.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5226.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5241.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_527.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5327.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5448.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5486.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_563.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5674.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5709.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5796.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5848.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5888.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_5942.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6017.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6035.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_620.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6229.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6256.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_635.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6357.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6358.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6482.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6524.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6593.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6675.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_671.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6807.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6917.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_6934.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7025.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7180.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_730.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7378.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7387.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7456.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7573.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_760.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7602.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7639.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_773.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7793.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_780.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7814.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_791.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7952.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_7977.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8135.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8206.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8218.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8273.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8331.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8439.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8508.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8643.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_8999.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9112.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9144.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9189.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9207.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9218.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9224.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9258.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9282.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9309.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9363.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9393.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9591.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9601.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9654.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9679.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9712.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9757.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_0_9986.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1029.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1087.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1188.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1192.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1326.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1338.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1496.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_155.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1579.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1604.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1622.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1662.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1696.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1741.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1844.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_1874.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_205.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2132.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_22.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2237.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2294.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2316.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2323.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2403.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2456.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2478.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_259.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2614.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2792.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_283.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2858.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2883.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2890.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2935.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_2943.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3007.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3016.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3021.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3093.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_315.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3239.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3357.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3405.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3443.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3633.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3760.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3775.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_3888.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_407.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4108.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4183.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4307.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4312.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4375.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_449.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4504.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4514.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4535.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4539.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4567.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_461.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4634.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4757.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4783.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4832.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4862.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4904.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4956.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_4994.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5027.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5080.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_51.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5113.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5143.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5158.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5196.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5349.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5433.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5462.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5593.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5668.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5716.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5720.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5790.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5814.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_584.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5896.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5909.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5981.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_5992.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6025.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6082.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6104.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6136.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6208.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6272.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6277.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6302.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6375.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6378.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6388.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6441.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6450.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6505.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6585.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6734.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_6788.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7153.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7297.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7425.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7428.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7445.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7695.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7739.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7740.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7799.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7865.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_7966.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_803.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8071.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8084.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8151.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_821.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8239.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8247.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8324.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8328.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8335.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8348.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8351.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8577.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8600.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8622.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8676.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8696.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8854.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_8922.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9029.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9087.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9152.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9198.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9250.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_929.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9306.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9376.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9408.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_949.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_970.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9733.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9758.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9818.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9828.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9964.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9984.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_10_9991.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1041.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1054.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1068.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1120.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1166.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_121.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1236.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1244.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1307.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1389.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1424.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1426.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1432.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1499.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1531.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1556.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1651.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1685.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1794.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1927.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1957.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_1969.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2040.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2046.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2131.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_220.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2238.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2261.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2264.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2384.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2422.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_243.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2509.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2673.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2783.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2789.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2794.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2811.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2857.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_291.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2952.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_2980.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_3091.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_3107.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/MONOCYTE/_11_3114.jpeg
# ...
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_5801.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_6368.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_7256.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_7979.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_8429.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_8506.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_8688.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_9019.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_9519.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_93_9651.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_1597.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_1970.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_2121.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_255.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_2573.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_3353.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_4199.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_4337.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_4992.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_5772.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_5893.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_602.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_6855.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_6913.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_7452.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_94_9898.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_2008.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_2550.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_3535.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_3865.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_4386.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_4402.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_4501.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_5558.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_5682.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_5911.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_7268.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_7399.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_8622.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_8927.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_9448.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_95_9932.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_1884.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_2248.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_2618.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_3254.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_4564.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_4803.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_4974.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_504.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_5686.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_5993.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_6379.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_7225.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_7391.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_8552.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_8604.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_96_9222.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_1083.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_1407.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_2291.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_2324.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_266.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_5018.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_555.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_6363.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_6817.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_7103.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_7492.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_7779.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_8216.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_8576.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_9818.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_97_9906.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_156.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_1601.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_1701.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_286.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_3060.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_3745.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_5078.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_5084.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_5779.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_5910.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_6603.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_6760.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_7150.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_7254.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_9274.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_98_9475.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_1394.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_2791.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_475.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_5644.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_6065.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_670.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_7087.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_7107.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_7158.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_7565.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_7999.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_8063.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_8096.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_8689.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_8759.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_99_8952.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_1276.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_2663.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_3730.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_4662.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_5057.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_5125.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_5178.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_5208.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_6001.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_6022.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_7478.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_7514.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_8230.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_8636.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_9075.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN/NEUTROPHIL/_9_9644.jpeg
#   inflating: /content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/labels.csv

# %%
class_names = ['EOSINOPHIL', 'LYMPHOCYTE', 'MONOCYTE', 'NEUTROPHIL']
nb_classes = len(class_names)
image_size = (120,120)

# %%
def load_data():

    datasets = ['/content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TRAIN','/content/drive/My Drive/blood_classification/dataset2-master/dataset2-master/images/TEST' ]
    images = []
    labels = []

    # iterate through training and test sets
    count =0
    for dataset in datasets:

        # iterate through folders in each dataset
        for folder in os.listdir(dataset):

            if folder in ['EOSINOPHIL']: label = 0
            elif folder in ['LYMPHOCYTE']: label = 1
            elif folder in ['MONOCYTE']: label = 2
            elif folder in ['NEUTROPHIL']: label = 3

            # iterate through each image in folder
            for file in tqdm(os.listdir(os.path.join(dataset, folder))):

                # get pathname of each image
                img_path = os.path.join(os.path.join(dataset, folder), file)

                # Open 
                image = cv2.imread(img_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                
                # add padding to the image to better detect cell at the edge
                image = cv2.copyMakeBorder(image,10,10,10,10,cv2.BORDER_CONSTANT,value=[198, 203, 208])
                
                #thresholding the image to get the target cell
                image1 = cv2.inRange(image,(80, 80, 180),(180, 170, 245))
                
                # openning errosion then dilation
                kernel = np.ones((3, 3), np.uint8)
                kernel1 = np.ones((5, 5), np.uint8)
                img_erosion = cv2.erode(image1, kernel, iterations=2)
                image1 = cv2.dilate(img_erosion, kernel1, iterations=5)
                
                #detecting the blood cell
                edgedImage = findEdges(image1)
                edgedContours = getImgContours(edgedImage)
                edgedBoxes =  getBoxes(edgedContours, image.copy())
                if len(edgedBoxes)==0:
                    count +=1
                    continue
                # get the large box and get its cordinate
                last = edgedBoxes[-1]
                max_x = int(max(last[:,0]))
                min_x = int( min(last[:,0]))
                max_y = int(max(last[:,1]))
                min_y = int(min(last[:,1]))
                
                # draw the contour and fill it 
                mask = np.zeros_like(image)
                cv2.drawContours(mask, edgedContours, len(edgedContours)-1, (255,255,255), -1) 
                
                # any pixel but the pixels inside the contour is zero
                image[mask==0] = 0
                
                # extract th blood cell
                image = image[min_y:max_y, min_x:max_x]

                if (np.size(image)==0):
                    count +=1
                    continue
                # resize th image
                image = cv2.resize(image, image_size)

                # Append the image and its corresponding label to the output
                images.append(image)
                labels.append(label)

    images = np.array(images, dtype = 'float32')
    labels = np.array(labels, dtype = 'int32')

    return images, labels

# %%
images, labels = load_data()
# Out:
# 100%|██████████| 2497/2497 [00:15<00:00, 160.71it/s]
# 100%|██████████| 2483/2483 [00:15<00:00, 160.88it/s]
# 100%|██████████| 2478/2478 [00:15<00:00, 161.69it/s]
# 100%|██████████| 2499/2499 [00:15<00:00, 159.60it/s]
# 100%|██████████| 623/623 [00:03<00:00, 159.12it/s]
# 100%|██████████| 620/620 [00:04<00:00, 150.96it/s]
# 100%|██████████| 620/620 [00:04<00:00, 151.39it/s]
# 100%|██████████| 624/624 [00:04<00:00, 151.74it/s]

# %% [markdown]
# All data (Training and Test combined) is shuffled and split into Training (80%), Validation (10%), Test (10%) sets

# %%
images, labels = shuffle(images, labels, random_state=10)

train_images, test_images, train_labels, test_labels = train_test_split(images, labels, test_size = 0.2)
test_images, val_images, test_labels, val_labels = train_test_split(test_images, test_labels, test_size = 0.5)

# %% [markdown]
# # Data Exploration
#
# - How many training, validation and testing examples do we have ? What shape are the images and labels ?
#
# - What is the proportion of each observed category ? Are the datasets balanced ?

# %%
n_train = train_labels.shape[0]
n_val = val_labels.shape[0]
n_test = test_labels.shape[0]

print("Number of training examples: {}".format(n_train))
print("Number of validation examples: {}".format(n_val))
print("Number of testing examples: {}".format(n_test))

print("Training images are of shape: {}".format(train_images.shape))
print("Training labels are of shape: {}".format(train_labels.shape))
print("Validation images are of shape: {}".format(val_images.shape))
print("Validation labels are of shape: {}".format(val_labels.shape))
print("Test images are of shape: {}".format(test_images.shape))
print("Test labels are of shape: {}".format(test_labels.shape))
# Out:
# Number of training examples: 9716
# Number of validation examples: 1215
# Number of testing examples: 1215
# Training images are of shape: (9716, 120, 120, 3)
# Training labels are of shape: (9716,)
# Validation images are of shape: (1215, 120, 120, 3)
# Validation labels are of shape: (1215,)
# Test images are of shape: (1215, 120, 120, 3)
# Test labels are of shape: (1215,)

# %%
_, train_counts = np.unique(train_labels, return_counts = True)
_, val_counts = np.unique(val_labels, return_counts = True)
_, test_counts = np.unique(test_labels, return_counts = True)

pd.DataFrame({'train': train_counts, "val": val_counts, "test": test_counts}, index = class_names).plot.bar()

plt.show()

# %%
plt.pie(train_counts,
        explode=(0, 0, 0, 0) , 
        labels=class_names,
        autopct='%1.1f%%')
plt.axis('equal')
plt.title('Proportion of each observed category')
plt.show()

# %% [markdown]
# A quick note on preparing the data: Pixel values in RGB images are represented by integers between 0..255. Data is normalised so pixel values are between 0..1 to increase computational speed.

# %%
train_images = train_images / 255.0 
val_images = val_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# Another sanity check: Visualise the data by displaying a single random image and 25 random images from the training set with corresponding labels.

# %%
def display_random_image (class_names, images, labels):
    print(len(images))
    index = np.random.randint(images.shape[0])
    plt.figure()
    plt.imshow(images[index])
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.title('Image #{}: '.format(index) + class_names[labels[index]])
    plt.show()
    
display_random_image (class_names, train_images, train_labels)
# Out:
# 9716

# %%
def display_examples(class_names, images, labels):
    fig = plt.figure(figsize = (10,10))
    fig.suptitle("Examples of images in the dataset", fontsize=16)
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        plt.xlabel(class_names[labels[i]])
    plt.show()
    
display_examples(class_names, train_images, train_labels)

# %% [markdown]
# # Custom built CNN
#
# This model contains a sequence of five Conv blocks containing combinations of SeparableConv2D, BatchNormalization, MaxPooling and Dropout layers. The output of the final Conv block is flattened and followed by three Fully Connected (FC) layers each with its own Dropout layer. A final FC layer is added with four units and a softmax activation for multiclass classification.

# %%
model1 = Sequential()

# First Conv block
model1.add(Conv2D(16 , (3,3) , padding = 'same' , activation = 'relu' , input_shape = (120,120,3)))
model1.add(Conv2D(16 , (3,3), padding = 'same' , activation = 'relu'))
model1.add(MaxPooling2D(pool_size = (2,2)))

# Second Conv block
model1.add(SeparableConv2D(32, (3,3), activation = 'relu', padding = 'same'))
model1.add(SeparableConv2D(32, (3,3), activation = 'relu', padding = 'same'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size = (2,2)))

# Third Conv block
model1.add(SeparableConv2D(64, (3,3), activation = 'relu', padding = 'same'))
model1.add(SeparableConv2D(64, (3,3), activation = 'relu', padding = 'same'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size = (2,2)))

# Forth Conv block
model1.add(SeparableConv2D(128, (3,3), activation = 'relu', padding = 'same'))
model1.add(SeparableConv2D(128, (3,3), activation = 'relu', padding = 'same'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size = (2,2)))
model1.add(Dropout(0.2))

# Fifth Conv block 
model1.add(SeparableConv2D(256, (3,3), activation = 'relu', padding = 'same'))
model1.add(SeparableConv2D(256, (3,3), activation = 'relu', padding = 'same'))
model1.add(BatchNormalization())
model1.add(MaxPooling2D(pool_size = (2,2)))
model1.add(Dropout(0.2))


# FC layer 
model1.add(Flatten())
model1.add(Dense(units = 512 , activation = 'tanh'))
model1.add(Dropout(0.7))
model1.add(Dense(units = 128 , activation = 'tanh'))
model1.add(Dropout(0.5))
model1.add(Dense(units = 64 , activation = 'tanh'))
model1.add(Dropout(0.3))

# Output layer
model1.add(Dense(units = 4 , activation = 'softmax'))

# Compile
model1.compile(optimizer = "adam" , loss = 'sparse_categorical_crossentropy' , metrics = ['accuracy'])
model1.summary()

# Implement callbacks 
checkpoint = ModelCheckpoint(filepath='best_model.hdf5', save_best_only=True, save_weights_only=False)
early_stop = EarlyStopping(monitor='val_loss', min_delta=0.1, patience=3, verbose = 1, mode='min', restore_best_weights = True)
learning_rate_reduction = ReduceLROnPlateau(
    monitor = 'val_accuracy', 
    patience = 2, 
    verbose = 1, 
    factor = 0.3, 
    min_lr = 0.000001)

# Train
history1 = model1.fit(
    train_images, 
    train_labels, 
    batch_size = 32, 
    epochs = 30, 
    validation_data=(val_images, val_labels), 
    callbacks=[learning_rate_reduction])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 120, 120, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 120, 120, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 60, 16)        0
# _________________________________________________________________
# separable_conv2d (SeparableC (None, 60, 60, 32)        688
# _________________________________________________________________
# separable_conv2d_1 (Separabl (None, 60, 60, 32)        1344
# _________________________________________________________________
# batch_normalization (BatchNo (None, 60, 60, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# separable_conv2d_2 (Separabl (None, 30, 30, 64)        2400
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 30, 30, 64)        4736
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 15, 15, 128)       8896
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 15, 15, 128)       17664
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 15, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 128)         0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 7, 7, 256)         34176
# _________________________________________________________________
# separable_conv2d_7 (Separabl (None, 7, 7, 256)         68096
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,397,028
# Trainable params: 1,396,068
# Non-trainable params: 960
# _________________________________________________________________
# Epoch 1/30
# 304/304 [==============================] - 219s 658ms/step - loss: 0.9722 - accuracy: 0.5438 - val_loss: 2.2339 - val_accuracy: 0.2370
# Epoch 2/30
# 304/304 [==============================] - 199s 655ms/step - loss: 0.5079 - accuracy: 0.8164 - val_loss: 3.5168 - val_accuracy: 0.4041
# Epoch 3/30
# 304/304 [==============================] - 199s 655ms/step - loss: 0.4407 - accuracy: 0.8407 - val_loss: 1.5234 - val_accuracy: 0.4354
# Epoch 4/30
# 304/304 [==============================] - 197s 648ms/step - loss: 0.3393 - accuracy: 0.8813 - val_loss: 1.9203 - val_accuracy: 0.6263
# Epoch 5/30
# 304/304 [==============================] - 196s 646ms/step - loss: 0.2938 - accuracy: 0.8965 - val_loss: 0.2838 - val_accuracy: 0.8955
# Epoch 6/30
# 304/304 [==============================] - 200s 657ms/step - loss: 0.2474 - accuracy: 0.9081 - val_loss: 1.8238 - val_accuracy: 0.5761
# Epoch 7/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.2195 - accuracy: 0.9192 - val_loss: 2.3973 - val_accuracy: 0.4979
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# Epoch 8/30
# 304/304 [==============================] - 196s 644ms/step - loss: 0.1497 - accuracy: 0.9473 - val_loss: 0.1618 - val_accuracy: 0.9498
# Epoch 9/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.1218 - accuracy: 0.9601 - val_loss: 0.0908 - val_accuracy: 0.9679
# Epoch 10/30
# 304/304 [==============================] - 197s 648ms/step - loss: 0.1077 - accuracy: 0.9655 - val_loss: 0.1096 - val_accuracy: 0.9588
# Epoch 11/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.1060 - accuracy: 0.9621 - val_loss: 0.1294 - val_accuracy: 0.9498
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# Epoch 12/30
# 304/304 [==============================] - 197s 647ms/step - loss: 0.0784 - accuracy: 0.9739 - val_loss: 0.0680 - val_accuracy: 0.9770
# Epoch 13/30
# 304/304 [==============================] - 197s 647ms/step - loss: 0.0719 - accuracy: 0.9778 - val_loss: 0.0683 - val_accuracy: 0.9778
# Epoch 14/30
# 304/304 [==============================] - 196s 644ms/step - loss: 0.0702 - accuracy: 0.9784 - val_loss: 0.4315 - val_accuracy: 0.8897
# Epoch 15/30
# 304/304 [==============================] - 196s 644ms/step - loss: 0.0659 - accuracy: 0.9791 - val_loss: 0.1201 - val_accuracy: 0.9638
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# Epoch 16/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.0690 - accuracy: 0.9773 - val_loss: 0.1409 - val_accuracy: 0.9638
# Epoch 17/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.0557 - accuracy: 0.9825 - val_loss: 0.0655 - val_accuracy: 0.9827
# Epoch 18/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.0575 - accuracy: 0.9831 - val_loss: 0.1023 - val_accuracy: 0.9712
# Epoch 19/30
# 304/304 [==============================] - 196s 645ms/step - loss: 0.0510 - accuracy: 0.9837 - val_loss: 0.0662 - val_accuracy: 0.9770
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# Epoch 20/30
# 304/304 [==============================] - 197s 648ms/step - loss: 0.0445 - accuracy: 0.9849 - val_loss: 0.0652 - val_accuracy: 0.9794
# Epoch 21/30
# 304/304 [==============================] - 195s 641ms/step - loss: 0.0521 - accuracy: 0.9823 - val_loss: 0.0683 - val_accuracy: 0.9753
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# Epoch 22/30
# 304/304 [==============================] - 194s 638ms/step - loss: 0.0499 - accuracy: 0.9814 - val_loss: 0.0653 - val_accuracy: 0.9761
# Epoch 23/30
# 304/304 [==============================] - 194s 638ms/step - loss: 0.0486 - accuracy: 0.9856 - val_loss: 0.0667 - val_accuracy: 0.9770
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 1e-06.
# Epoch 24/30
# 304/304 [==============================] - 195s 640ms/step - loss: 0.0514 - accuracy: 0.9826 - val_loss: 0.0661 - val_accuracy: 0.9778
# Epoch 25/30
# 304/304 [==============================] - 194s 640ms/step - loss: 0.0597 - accuracy: 0.9820 - val_loss: 0.0668 - val_accuracy: 0.9778
# Epoch 26/30
# 304/304 [==============================] - 195s 641ms/step - loss: 0.0478 - accuracy: 0.9828 - val_loss: 0.0720 - val_accuracy: 0.9770
# Epoch 27/30
# 304/304 [==============================] - 195s 642ms/step - loss: 0.0509 - accuracy: 0.9828 - val_loss: 0.0697 - val_accuracy: 0.9761
# Epoch 28/30
# 304/304 [==============================] - 195s 641ms/step - loss: 0.0488 - accuracy: 0.9859 - val_loss: 0.0674 - val_accuracy: 0.9770
# Epoch 29/30
# 304/304 [==============================] - 194s 640ms/step - loss: 0.0534 - accuracy: 0.9831 - val_loss: 0.0689 - val_accuracy: 0.9761
# Epoch 30/30
# 304/304 [==============================] - 195s 643ms/step - loss: 0.0448 - accuracy: 0.9870 - val_loss: 0.0686 - val_accuracy: 0.9761

# %% [markdown]
# # Evaluating performance
#
# Following model training I emplemented a helper function to plot Accuracy vs Epoch and Loss vs Epoch for both the Training and Validation sets

# %%
def plot_accuracy_loss_chart(history):
    epochs = [i for i in range(30)]
    fig , ax = plt.subplots(1,2)
    train_acc = history.history['accuracy']
    train_loss = history.history['loss']
    val_acc = history.history['val_accuracy']
    val_loss = history.history['val_loss']
    fig.set_size_inches(20,10)
    ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
    ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
    ax[0].set_title('Training & Validation Accuracy')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")

    ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
    ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
    ax[1].set_title('Training & Validation Loss')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Training & Validation Loss")
    plt.show()

# %%
plot_accuracy_loss_chart(history1)

# %% [markdown]
# Lets evaluate the model on test data to find the loss and accuracy:

# %%
results = model1.evaluate(test_images, test_labels)

print("Loss of the model  is - test ", results[0])
print("Accuracy of the model is - test", results[1]*100, "%")


results = model1.evaluate(val_images, val_labels)

print("Loss of the model  is - val ", results[0])
print("Accuracy of the model is - val", results[1]*100, "%")

results = model1.evaluate(train_images, train_labels)

print("Loss of the model  is - train ", results[0])
print("Accuracy of the model is - train", results[1]*100, "%")
# Out:
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0878 - accuracy: 0.9728
# Loss of the model  is - test  0.08779078722000122
# Accuracy of the model is - test 97.28395342826843 %
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0686 - accuracy: 0.9761
# Loss of the model  is - val  0.06859273463487625
# Accuracy of the model is - val 97.61316776275635 %
# 304/304 [==============================] - 50s 164ms/step - loss: 0.0290 - accuracy: 0.9910
# Loss of the model  is - train  0.028951551765203476
# Accuracy of the model is - train 99.10457134246826 %

# %% [markdown]
# Model (and weights) are saved after training. The best model and its weights can also be saved using the ModelCheckpoint callback if "EarlyStopping" is activated in the Model.fit phase. [More on this here](https://machinelearningmastery.com/how-to-stop-training-deep-neural-networks-at-the-right-time-using-early-stopping/)
#
# I decided against using EarlyStopping, but I will try to include it in future work on this dataset.

# %%
model1.save('/content/drive/MyDrive/Bloodcell_Classification_Model1_Custom_Build_10_epochs.h5')

# %%
from sklearn.metrics import classification_report

predictions = model1.predict(test_images)
predictions = np.argmax(predictions,axis=1)
predictions[:15]
# Out:
# array([1, 1, 3, 0, 2, 0, 2, 2, 0, 2, 1, 2, 2, 1, 0])

# %%
print(classification_report(
    test_labels, 
    predictions, 
    target_names = ['EOSINOPHIL (Class 0)', 'LYMPHOCYTE (Class 1)', 'MONOCYTE (Class 2)', 'NEUTROPHIL (Class 3)']))
# Out:
#                       precision    recall  f1-score   support
#
# EOSINOPHIL (Class 0)       0.97      0.94      0.95       324
# LYMPHOCYTE (Class 1)       1.00      1.00      1.00       276
#   MONOCYTE (Class 2)       0.99      0.99      0.99       290
# NEUTROPHIL (Class 3)       0.95      0.96      0.95       325
#
#             accuracy                           0.97      1215
#            macro avg       0.97      0.97      0.97      1215
#         weighted avg       0.97      0.97      0.97      1215

# %% [markdown]
# A second helper function is created to plot confusion matrix. which will give us a better visualization of these results.

# %%
cm = confusion_matrix(test_labels, predictions)
cm = pd.DataFrame(cm, index = ['0', '1', '2', '3'], columns = ['0', '1', '2', '3'])
cm
# Out:
#      0    1    2    3
# 0  306    1    2   15
# 1    0  276    0    0
# 2    0    0  288    2
# 3   11    0    2  312

# %%
def plot_confusion_matrix (cm):
    plt.figure(figsize = (10,10))
    sns.heatmap(
        cm, 
        cmap = 'Blues', 
        linecolor = 'black', 
        linewidth = 1, 
        annot = True, 
        fmt = '', 
        xticklabels = class_names, 
        yticklabels = class_names)
    
plot_confusion_matrix(cm)
